# %%
(eval-and-compile
 (import sys)
 (sys.path.append "/home/riktor/.hy"))
(eval-and-compile
 (require (utils (*)))
 (import-sci))

# %%
(setf dataset (pd.DataFrame (np.random.random '(10))))

# %%
dataset
# Out:
#           0
# 0  0.639775
# 1  0.606651
# 2  0.898648
# 3  0.917429
# 4  0.807688
# 5  0.404295
# 6  0.532457
# 7  0.123349
# 8  0.753912
# 9  0.554072

# %%
(dfvis dataset)
# Out:
# /tmp/tmpfayyx89o.png

# %%
(export-nb "Untitled13.ipynb" "convert-test.ipynb")
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/site-packages/calysto_hy/kernel.py", line 98, in do_execute_direct
#     eval(code, self.env)
#   File "In [5]", line 2, in <module>
#   File "/home/riktor/.hy/utils.hy", line 131, in export_nb
#     (_collect (get-img-cell text) into cells))
#   File "/home/riktor/.hy/utils.hy", line 112, in get_img_cell
#     (output (nbf.v4.new_output 'display-data)))
#   File "/home/riktor/.hy/utils.hy", line 113, in _hy_anon_fn_5
#     (.append (. outputs data) {"image/png" (base64.encodestring (.read (open path 'rb)))})
# NameError: name 'outputs' is not defined
